# %%
import pandas as pd
import numpy as np
import csv

# %%
animals = ['tiger','lion']
a = pd.Series(animals)
a.index


places = { 'Agra' : 'Taj Mahal',
            'Chicago' : 'Sears'  
}

p = pd.Series(places)
p
# Out:
# Agra       Taj Mahal
# Chicago        Sears
# dtype: object

# %%
with open('/Users/VK/Desktop/UChicago/playground/python/NFLX.csv') as csvh:
    data = csv.reader(csvh)
    for line in data:
        p = pd.Series(line)
# Out:
# 0    TIMESTAMP
# 1        CLOSE
# 2         HIGH
# 3          LOW
# 4         OPEN
# 5       VOLUME
# dtype: object
# 0    2017-07-31 08:30:00
# 1                 184.25
# 2                 184.74
# 3                  184.2
# 4                 184.26
# 5                  68133
# dtype: object
# 0    2017-07-31 08:31:00
# 1                 184.26
# 2               184.8099
# 3                 184.25
# 4               184.8099
# 5                  26109
# dtype: object
# 0    2017-07-31 08:32:00
# 1                 184.24
# 2                184.611
# 3                 184.22
# 4                 184.47
# 5                  17313
# dtype: object
# 0    2017-07-31 08:33:00
# 1               184.3541
# 2               184.3541
# 3                 184.01
# 4                 184.22
# 5                  13824
# dtype: object
# 0    2017-07-31 08:34:00
# 1                  183.8
# 2               184.2725
# 3                 183.51
# 4               184.2725
# 5                  25222
# ...

# %%
purchase_1 = pd.Series({'Name': 'Chris',
                        'Item Purchased': 'Dog Food',
                        'Cost': 22.50})
purchase_2 = pd.Series({'Name': 'Kevyn',
                        'Item Purchased': 'Kitty Litter',
                        'Cost': 2.50})
purchase_3 = pd.Series({'Name': 'Vinod',
                        'Item Purchased': 'Bird Seed',
                        'Cost': 5.00})

df = pd.DataFrame([purchase_1, purchase_2, purchase_3], index=['Store 1', 'Store 1', 'Store 2'])

df['Item Purchased']
# Out:
# Store 1        Dog Food
# Store 1    Kitty Litter
# Store 2       Bird Seed
# Name: Item Purchased, dtype: object

# %%
import pandas_datareader.data as wb
import datetime
import csv

tickers = []

if __name__ == "__main__":
        etfFile = '/Users/VK/Desktop/UChicago/Capstone/scripts/etfs.txt'
        etf = open(etfFile,'r')

        for row in etf:
                ticker = row.strip()
                print (ticker)
                web_df = wb.DataReader(ticker, 'yahoo',
                       datetime.date(2017,10,1),
                       datetime.date(2018,1,15))

                
                high = web_df['High']
                low = web_df['Low']
                
                
                
                print (high-low)
#               csvhandle = web_df.to_csv()
#               for r in csvhandle:
#                       print (r)

#print (tickers)
# Out:
# TQQQ
# Date
# 2017-10-02    2.930000
# 2017-10-03    1.430000
# 2017-10-04    2.000000
# 2017-10-05    2.660004
# 2017-10-06    1.650002
# 2017-10-09    1.690002
# 2017-10-10    2.860001
# 2017-10-11    1.750000
# 2017-10-12    1.820000
# 2017-10-13    0.790000
# 2017-10-16    1.209999
# 2017-10-17    1.190002
# 2017-10-18    1.339997
# 2017-10-19    2.580002
# 2017-10-20    1.219993
# 2017-10-23    3.640000
# 2017-10-24    2.059998
# 2017-10-25    4.510002
# 2017-10-26    1.890000
# 2017-10-27    5.559997
# 2017-10-30    3.000000
# 2017-10-31    1.839996
# 2017-11-01    3.409989
# 2017-11-02    3.120010
# 2017-11-03    3.699997
# 2017-11-06    1.949997
# 2017-11-07    1.929992
# 2017-11-08    2.389999
# 2017-11-09    4.350006
# 2017-11-10    1.919999
#                 ...
# 2017-12-01    7.940003
# 2017-12-04    8.039994
# 2017-12-05    6.339996
# 2017-12-06    4.289993
# 2017-12-07    2.910004
# 2017-12-08    2.779999
# 2017-12-11    3.130005
# 2017-12-12    2.099991
# ...
